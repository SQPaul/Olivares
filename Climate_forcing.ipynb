# %% [markdown]
# # Climate forcing
# ## Upper Olivares catchment - january, 2023
# #### Paul Sandoval Quilodrán - https://github.com/SQPaul/Olivares

# %% [markdown]
# #### import packages

# %%
from osgeo import gdal
import pandas as pd
import rasterio as rio
from rasterio.plot import show
import numpy as np
import xarray as xr
import cftime
# geospatial
#import rioxarray as rioxr
#import regionmask

# %%
#Selecting mask 
#mask_tif = rio.open("/home/phi/Desktop/Projects/Juncal_norte/GIS/Juncal_Norte_mask_dem_v0/juncalnorte_mask_v0.tif") #Linux
mask_tif = rio.open(r"P:\Projects\Olivares\GIS\real_mask2.tif") #windows
mask_array = mask_tif.read(1)

# %% [markdown]
# #### clip netcdf in cdo - linux
# * ncks -d x,374779.0,414779.0 -d y,6290050.0,6346050.0 input.nc output.nc

# %% [markdown]
# ### 1.- Precipitation

# %%
#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
pp_cdf = xr.open_dataset("/media/phi/Hard_disk/Projects/Olivares/climate_forcing/PP.nc") #windows
pp_cdf["pr"][0]

# %%
#Reading pp with rasterio to convert it to PCRaster maps
pp = rio.open("/media/phi/Hard_disk/Projects/Olivares/climate_forcing/PP.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

# %%
#f = 2.47 #adjustment factor reanalisis product and observed data
for i in range(len(pp_cdf["pr"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = "/media/phi/Hard_disk/Projects/Olivares/climate_forcing/pp/pp00000"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = "/media/phi/Hard_disk/Projects/Olivares/climate_forcing/pp/pp00000"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    pp_it = pp.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(pp_it,1)
    maps.close()
    print(i)

# %% [markdown]
# ### 2.- Tmax

# %%
#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
tmax_cdf = xr.open_dataset(r"P:\Projects\Olivares\climate_forcing\TMAX.nc") #windows
tmax_cdf

#Reading pp with rasterio to convert it to PCRaster maps
tmax = rio.open(r"P:\Projects\Olivares\climate_forcing\TMAX.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

for i in range(len(tmax_cdf["tmax"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tmax\tmax000"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tmax\tmax000"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    tmax_it = tmax.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(tmax_it,1)
    maps.close()
    print(i)
# Out:
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.001
# 0
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.002
# 1
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.003
# 2
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.004
# 3
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.005
# 4
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.006
# 5
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.007
# 6
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.008
# 7
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.009
# 8
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.010
# 9
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.011
# 10
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.012
# 11
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.013
# 12
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.014
# 13
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.015
# 14
# P:\Projects\Olivares\climate_forcing\tmax\tmax0000.016
# 15
# ...

# %% [markdown]
# ### 3.- Tmin

# %%
#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
tmin_cdf = xr.open_dataset(r"P:\Projects\Olivares\climate_forcing\TMIN.nc") #windows
tmin_cdf

#Reading pp with rasterio to convert it to PCRaster maps
tmin = rio.open(r"P:\Projects\Olivares\climate_forcing\TMIN.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

for i in range(len(tmin_cdf["tmin"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tmin\tmin000"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tmin\tmin000"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    tmin_it = tmin.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(tmin_it,1)
    maps.close()
    print(i)
# Out:
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.001
# 0
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.002
# 1
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.003
# 2
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.004
# 3
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.005
# 4
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.006
# 5
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.007
# 6
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.008
# 7
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.009
# 8
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.010
# 9
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.011
# 10
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.012
# 11
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.013
# 12
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.014
# 13
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.015
# 14
# P:\Projects\Olivares\climate_forcing\tmin\tmin0000.016
# 15
# ...

# %% [markdown]
# #### 4.- Tavg

# %%
#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
tavg_cdf = xr.open_dataset(r"P:\Projects\Olivares\climate_forcing\SWin.nc") #windows
tavg_cdf
#Reading pp with rasterio to convert it to PCRaster maps
tavg = rio.open(r"P:\Projects\Olivares\climate_forcing\SWin.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

for i in range(len(tavg_cdf["t2m"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tavg\tavg000"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\tavg\tavg000"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    tavg_it = tavg.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(tavg_it,1)
    maps.close()
    print(i)
# Out:
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.001
# 0
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.002
# 1
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.003
# 2
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.004
# 3
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.005
# 4
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.006
# 5
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.007
# 6
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.008
# 7
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.009
# 8
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.010
# 9
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.011
# 10
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.012
# 11
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.013
# 12
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.014
# 13
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.015
# 14
# P:\Projects\Olivares\climate_forcing\tavg\tavg0000.016
# 15
# ...

# %% [markdown]
# #### 4.- SWin

# %%
#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
swin_cdf = xr.open_dataset(r"P:\Projects\Olivares\climate_forcing\SWIN.nc") #windows
swin_cdf
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8308, y: 112, x: 80)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-01-01T12:00:00 ... 2022-09-29T12:00:00
#   * x        (x) float64 3.75e+05 3.755e+05 3.76e+05 ... 4.14e+05 4.145e+05
#   * y        (y) float64 6.29e+06 6.291e+06 6.291e+06 ... 6.345e+06 6.346e+06
# Data variables:
#     SWin     (time, y, x) float64 ...
# Attributes:
#     history:  Mon Jan 16 09:58:20 2023: ncks -d x,374779.0,414779.0 -d y,6290...
#     NCO:      netCDF Operators version 5.0.6 (Homepage = http://nco.sf.net, C...

# %%
#Reading pp with rasterio to convert it to PCRaster maps
swin = rio.open(r"P:\Projects\Olivares\climate_forcing\SWIN.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

for i in range(len(swin_cdf["SWin"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\swin\swin000"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\swin\swin000"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    swin_it = swin.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(swin_it,1)
    maps.close()
    print(i)
# Out:
# P:\Projects\Olivares\climate_forcing\swin\swin0000.001
# 0
# P:\Projects\Olivares\climate_forcing\swin\swin0000.002
# 1
# P:\Projects\Olivares\climate_forcing\swin\swin0000.003
# 2
# P:\Projects\Olivares\climate_forcing\swin\swin0000.004
# 3
# P:\Projects\Olivares\climate_forcing\swin\swin0000.005
# 4
# P:\Projects\Olivares\climate_forcing\swin\swin0000.006
# 5
# P:\Projects\Olivares\climate_forcing\swin\swin0000.007
# 6
# P:\Projects\Olivares\climate_forcing\swin\swin0000.008
# 7
# P:\Projects\Olivares\climate_forcing\swin\swin0000.009
# 8
# P:\Projects\Olivares\climate_forcing\swin\swin0000.010
# 9
# P:\Projects\Olivares\climate_forcing\swin\swin0000.011
# 10
# P:\Projects\Olivares\climate_forcing\swin\swin0000.012
# 11
# P:\Projects\Olivares\climate_forcing\swin\swin0000.013
# 12
# P:\Projects\Olivares\climate_forcing\swin\swin0000.014
# 13
# P:\Projects\Olivares\climate_forcing\swin\swin0000.015
# 14
# P:\Projects\Olivares\climate_forcing\swin\swin0000.016
# 15
# ...

# %%
#### 5.- SWout

#Import NetCDF to read the information
#pp_cdf = xr.open_dataset("/home/phi/Desktop/Projects/Juncal_norte/Climate_forcing/CR2MET_PR_JUNCALNORTE_500m.nc") #,decode_cf=False
swout_cdf = xr.open_dataset(r"P:\Projects\Olivares\climate_forcing\SWOUT.nc") #windows
swout_cdf

#Reading pp with rasterio to convert it to PCRaster maps
swout = rio.open(r"P:\Projects\Olivares\climate_forcing\SWOUT.nc") #linux
#pp = rio.open(r"P:\Projects\Olivares\GIS\climate_forcing\GWR_ERA5LAND_PR_OLIVARES_500m.nc") #windows

for i in range(len(swout_cdf["SWout"])):
    ii = i+1
    if ii < 10000:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\swout\swout00"+str(f_value) #linux
        #name = "P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    else:
        value = ii/1000
        f_value = "{:.3f}".format(value)
        name = r"P:\Projects\Olivares\climate_forcing\swout\swout00"+str(f_value) #linux
        #name = r"P:\Projects\Olivares\GIS\climate_forcing\pp\pp40000"+str(f_value) #windows
    print(name)
    swout_it = swout.read(ii)
    maps = rio.open(
    str(name),"w",
    driver = "PCRaster",
    pcraster_valuescale = "VS_SCALAR",
    height = mask_tif.shape[0],
    width = mask_tif.shape[1],
    count = 1,
    nodata = mask_tif.nodata,
    dtype = np.float32,
    crs = 32719,
    transform = mask_tif.transform)
    maps.write(swout_it,1)
    maps.close()
    print(i)
# Out:
# P:\Projects\Olivares\climate_forcing\swout\swout000.001
# 0
# P:\Projects\Olivares\climate_forcing\swout\swout000.002
# 1
# P:\Projects\Olivares\climate_forcing\swout\swout000.003
# 2
# P:\Projects\Olivares\climate_forcing\swout\swout000.004
# 3
# P:\Projects\Olivares\climate_forcing\swout\swout000.005
# 4
# P:\Projects\Olivares\climate_forcing\swout\swout000.006
# 5
# P:\Projects\Olivares\climate_forcing\swout\swout000.007
# 6
# P:\Projects\Olivares\climate_forcing\swout\swout000.008
# 7
# P:\Projects\Olivares\climate_forcing\swout\swout000.009
# 8
# P:\Projects\Olivares\climate_forcing\swout\swout000.010
# 9
# P:\Projects\Olivares\climate_forcing\swout\swout000.011
# 10
# P:\Projects\Olivares\climate_forcing\swout\swout000.012
# 11
# P:\Projects\Olivares\climate_forcing\swout\swout000.013
# 12
# P:\Projects\Olivares\climate_forcing\swout\swout000.014
# 13
# P:\Projects\Olivares\climate_forcing\swout\swout000.015
# 14
# P:\Projects\Olivares\climate_forcing\swout\swout000.016
# 15
# ...
